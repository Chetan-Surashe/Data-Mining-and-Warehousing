# %% [markdown]
# #**DMW 1**
#
# #*Dataset: modified_ethnic.csv*

# %%
#importing pandas libraries
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#importing dataset
data = pd.read_csv('modified_ethnic.csv')
data
# Out:
#                      Position State Sex MaritalDesc CitizenDesc  \
# 0                Accountant I   NaN   F     Married  US Citizen
# 1                Accountant I    MA  M     Divorced  US Citizen
# 2                Accountant I    MA  M       Single         NaN
# 3    Administrative Assistant    MA   F         NaN  US Citizen
# 4                         NaN    MA   F      Single  US Citizen
# ..                        ...   ...  ..         ...         ...
# 305      Sr. Network Engineer    CT   F     Married  US Citizen
# 306      Sr. Network Engineer    MA  M      Married  US Citizen
# 307                       NaN    MA  M      Married  US Citizen
# 308      Sr. Network Engineer    CT  M          NaN  US Citizen
# 309      Sr. Network Engineer    MA   F     Widowed  US Citizen
#
#          EmploymentStatus     Department  Salaries   age  \
# 0                  Active  Admin Offices    674.28   NaN
# 1                  Active  Admin Offices    674.28  50.0
# ...

# %%
# Print first 5 Rows only
data.head(5)
# Out:
#                    Position State Sex MaritalDesc CitizenDesc  \
# 0              Accountant I   NaN   F     Married  US Citizen
# 1              Accountant I    MA  M     Divorced  US Citizen
# 2              Accountant I    MA  M       Single         NaN
# 3  Administrative Assistant    MA   F         NaN  US Citizen
# 4                       NaN    MA   F      Single  US Citizen
#
#        EmploymentStatus     Department  Salaries   age  \
# 0                Active  Admin Offices    674.28   NaN
# 1                Active  Admin Offices    674.28  50.0
# 2                Active  Admin Offices    674.28  43.0
# 3  Terminated for Cause  Admin Offices  47822.00  44.0
# 4                Active  Admin Offices       NaN  33.0
#
#                         Race
# 0  Black or African American
# 1  Black or African American
# 2                      White
# 3                        NaN
# 4                      White

# %%
# Print all the columns name
print(data.columns)
# Out:
# Index(['Position', 'State', 'Sex', 'MaritalDesc', 'CitizenDesc',
#        'EmploymentStatus', 'Department', 'Salaries', 'age', 'Race'],
#       dtype='object')

# %%
# Print the Data Types of Each column
data.dtypes
# Out:
# Position             object
# State                object
# Sex                  object
# MaritalDesc          object
# CitizenDesc          object
# EmploymentStatus     object
# Department           object
# Salaries            float64
# age                 float64
# Race                 object
# dtype: object

# %%
data.shape
# Out:
# (310, 10)

# %%
data.describe()
# Out:
#             Salaries         age
# count     278.000000  275.000000
# mean    36725.396007   38.592727
# std     20997.074151    9.290994
# min        75.000000   23.000000
# 25%     24294.772500   30.500000
# 50%     35568.315000   39.000000
# 75%     51452.895000   46.000000
# max    108304.000000   54.000000

# %%
data.boxplot()
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Position          267 non-null    object
#  1   State             275 non-null    object
#  2   Sex               276 non-null    object
#  3   MaritalDesc       281 non-null    object
#  4   CitizenDesc       283 non-null    object
#  5   EmploymentStatus  278 non-null    object
#  6   Department        292 non-null    object
#  7   Salaries          278 non-null    float64
#  8   age               275 non-null    float64
#  9   Race              285 non-null    object
# dtypes: float64(2), object(8)
# memory usage: 24.3+ KB

# %%
# prepocessing steps
data.isnull().sum()
# Out:
# Position            43
# State               35
# Sex                 34
# MaritalDesc         29
# CitizenDesc         27
# EmploymentStatus    32
# Department          18
# Salaries            32
# age                 35
# Race                25
# dtype: int64

# %%
# Find the missing values from Rating Column and repalce by Median value
# user Defined function
def impute_median(series):
    return series.fillna(series.median())

# Apply user defined function into Rating Column:
data.Salaries=data['Salaries'].transform(impute_median)

# %%
# See the Rating Column Values
data[23:24]
# Out:
#               Position State Sex MaritalDesc CitizenDesc EmploymentStatus  \
# 23  Area Sales Manager    IN   F         NaN         NaN           Active
#
#    Department  Salaries   age   Race
# 23      Sales  96708.02  37.0  White

# %%
data.isnull().sum()
# Out:
# Position            43
# State               35
# Sex                 34
# MaritalDesc         29
# CitizenDesc         27
# EmploymentStatus    32
# Department          18
# Salaries             0
# age                 35
# Race                25
# dtype: int64

# %%
data['Position'].fillna(str(data['Position'].mode().values[0]),inplace=True)

# %%
data[31:310]
# Out:
#                     Position State  Sex MaritalDesc CitizenDesc  \
# 31        Area Sales Manager    ND   M          NaN  US Citizen
# 32   Production Technician I   NaN    F      Single  US Citizen
# 33              BI Developer    MA    F     Married  US Citizen
# 34              BI Developer    MA   M       Single  US Citizen
# 35              BI Developer   NaN  NaN     Married  US Citizen
# ..                       ...   ...  ...         ...         ...
# 305     Sr. Network Engineer    CT    F     Married  US Citizen
# 306     Sr. Network Engineer    MA   M      Married  US Citizen
# 307  Production Technician I    MA   M      Married  US Citizen
# 308     Sr. Network Engineer    CT   M          NaN  US Citizen
# 309     Sr. Network Engineer    MA    F     Widowed  US Citizen
#
#      EmploymentStatus Department   Salaries   age                       Race
# 31             Active      Sales  60434.670  48.0                      White
# ...

# %%
data.isnull().sum()
# Out:
# Position             0
# State               35
# Sex                 34
# MaritalDesc         29
# CitizenDesc         27
# EmploymentStatus    32
# Department          18
# Salaries             0
# age                 35
# Race                25
# dtype: int64

# %%
data['State'].fillna(str(data['Position'].mode().values[0]),inplace=True)

# %%
data['Sex'].fillna(str(data['Sex'].mode().values[0]),inplace=True)

# %%
data['MaritalDesc'].fillna(str(data['MaritalDesc'].mode().values[0]),inplace=True)

# %%
data['CitizenDesc'].fillna(str(data['CitizenDesc'].mode().values[0]),inplace=True)

# %%
data['EmploymentStatus'].fillna(str(data['EmploymentStatus'].mode().values[0]),inplace=True)

# %%
data['Department'].fillna(str(data['Department'].mode().values[0]),inplace=True)

# %%
data['Race'].fillna(str(data['Race'].mode().values[0]),inplace=True)

# %%
data.isnull().sum()
# Out:
# Position             0
# State                0
# Sex                  0
# MaritalDesc          0
# CitizenDesc          0
# EmploymentStatus     0
# Department           0
# Salaries             0
# age                 35
# Race                 0
# dtype: int64

# %%
# Find the missing values from Rating Column and repalce by Median value
# user Defined function
def impute_median(series):
    return series.fillna(series.median())

# Apply user defined function into Rating Column:
data.age=data['age'].transform(impute_median)

# %%
# See the Rating Column Values
data[23:24]
# Out:
#               Position State Sex MaritalDesc CitizenDesc EmploymentStatus  \
# 23  Area Sales Manager    IN   F      Single  US Citizen           Active
#
#    Department  Salaries   age   Race
# 23      Sales  96708.02  37.0  White

# %%
data.isnull().sum()
# Out:
# Position            0
# State               0
# Sex                 0
# MaritalDesc         0
# CitizenDesc         0
# EmploymentStatus    0
# Department          0
# Salaries            0
# age                 0
# Race                0
# dtype: int64

# %%
data.dtypes
# Out:
# Position             object
# State                object
# Sex                  object
# MaritalDesc          object
# CitizenDesc          object
# EmploymentStatus     object
# Department           object
# Salaries            float64
# age                 float64
# Race                 object
# dtype: object

# %%
data.describe
# Out:
# <bound method NDFrame.describe of                      Position                    State Sex MaritalDesc  \
# 0                Accountant I  Production Technician I   F     Married
# 1                Accountant I                       MA  M     Divorced
# 2                Accountant I                       MA  M       Single
# 3    Administrative Assistant                       MA   F      Single
# 4     Production Technician I                       MA   F      Single
# ..                        ...                      ...  ..         ...
# 305      Sr. Network Engineer                       CT   F     Married
# 306      Sr. Network Engineer                       MA  M      Married
# 307   Production Technician I                       MA  M      Married
# 308      Sr. Network Engineer                       CT  M       Single
# 309      Sr. Network Engineer                       MA   F     Widowed
#
#     CitizenDesc      EmploymentStatus     Department   Salaries   age  \
# ...

# %%
# Group the App Based on the Category
grp=data.groupby('Position')
x=grp['Salaries'].agg(np.mean)

# %%
result = sorted(x.items(), key=lambda x: x[1], reverse=True)[:5]
print
import operator
result1=dict(sorted(x.items(), key=operator.itemgetter(1), reverse=True)[:5])
print(x.max())
x.hist()
# Out:
# 71293.67666666667
# <Axes: >

# %%
x.hist()
y=grp['age'].agg(np.sum)
result1 = sorted(y.items(), key=lambda x: x[1], reverse=True)[:5]

# %%
fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.bar(x,y, color='g')
ax2.plot(x, y, 'b')
ax1.set_xlabel('Position')
ax1.set_ylabel('age', color='g')
ax2.set_ylabel('Salaries', color='b')
ax1.set_xticklabels(x,rotation='vertical',size=8)
plt.show()
# Out:
# <ipython-input-50-02cc053487fb>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(x,rotation='vertical',size=8)

# %%
plt.figure(figsize=(16,5))
plt.plot(x,'r--',color='r')
plt.xticks(rotation=90)
plt.title("age")
plt.xlabel('Position')
plt.ylabel('Salaries')
plt.show()
# Out:
# <ipython-input-51-b46014b651ed>:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,'r--',color='r')

# %%
plt.figure(figsize=(16,5))
plt.plot(y,'r--',color='r')
plt.xticks(rotation=90)
plt.title("Department")
plt.xlabel('Salaries')
plt.ylabel('age')
plt.show()
# Out:
# <ipython-input-52-1cdb5fa1e2f8>:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(y,'r--',color='r')

# %%
plt.figure(figsize=(16,5))
plt.plot(y,'r--',color='b')
plt.xticks(rotation=90)
plt.title("Department")
plt.xlabel('Positions')
plt.ylabel('Sex')
plt.show()
# Out:
# <ipython-input-54-0ae3428c3d24>:2: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r--" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(y,'r--',color='b')

# %% [markdown]
# #**DMW 2**
#
# #*Dataset: Modified_ethnic.csv*

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import numpy as np

# %%
data = pd.read_csv('modified_ethnic.csv')
data
# Out:
#                      Position State Sex MaritalDesc CitizenDesc  \
# 0                Accountant I   NaN   F     Married  US Citizen
# 1                Accountant I    MA  M     Divorced  US Citizen
# 2                Accountant I    MA  M       Single         NaN
# 3    Administrative Assistant    MA   F         NaN  US Citizen
# 4                         NaN    MA   F      Single  US Citizen
# ..                        ...   ...  ..         ...         ...
# 305      Sr. Network Engineer    CT   F     Married  US Citizen
# 306      Sr. Network Engineer    MA  M      Married  US Citizen
# 307                       NaN    MA  M      Married  US Citizen
# 308      Sr. Network Engineer    CT  M          NaN  US Citizen
# 309      Sr. Network Engineer    MA   F     Widowed  US Citizen
#
#          EmploymentStatus     Department  Salaries   age  \
# 0                  Active  Admin Offices    674.28   NaN
# 1                  Active  Admin Offices    674.28  50.0
# ...

# %%
# a) Find standard deviation, variance of every numerical attribute
std_deviation = data.std()
variance = data.var()
print("Standard Deviation:\n", std_deviation)
print("\nVariance:\n", variance)
# Out:
# Standard Deviation:
#  Salaries    20997.074151
# age             9.290994
# dtype: float64
#
# Variance:
#  Salaries    4.408771e+08
# age         8.632257e+01
# dtype: float64
# <ipython-input-4-a2f8eeb719da>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   std_deviation = data.std()
# <ipython-input-4-a2f8eeb719da>:3: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   variance = data.var()

# %%
# b) Find covariance and perform Correlation analysis using Correlation coefficient
#Variance is a measure of magnitude because it is expressed as a number.
#Covariance, on the other hand, describes the direction of a relationship between two variables.
#It is defined as a positive or negative value rather than a number.
covariance_matrix = data.cov()
correlation_matrix = data.corr()
print("\nCovariance Matrix:\n", covariance_matrix)
print("\nCorrelation Matrix:\n", correlation_matrix)
# Out:
# Covariance Matrix:
#                Salaries          age
# Salaries  4.408771e+08 -4078.367975
# age      -4.078368e+03    86.322575
#
# Correlation Matrix:
#            Salaries       age
# Salaries  1.000000 -0.020286
# age      -0.020286  1.000000
# <ipython-input-5-fc51de66c3b5>:5: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   covariance_matrix = data.cov()
# <ipython-input-5-fc51de66c3b5>:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = data.corr()

# %%
# c) How many independent features are present in the given dataset?
#Correlation finds the direction of the relationship along with the degree of the relationship.
independent_features = np.linalg.matrix_rank(data.corr())
print("\nNumber of independent features:", independent_features)
# Out:
# Number of independent features: 12
# <ipython-input-10-43e31aaa1a86>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   independent_features = np.linalg.matrix_rank(data.corr())

# %%
# d) Can we identify unwanted features?
# we can analyze correlation coefficients to identify features strongly correlated with each other.
# Features with high correlation might be candidates for removal if redundancy is present.
# Features with high correlation might be candidates for removal.
#Correlation shows us both, the direction and magnitude of how two quantities vary with each other.
unwanted_features = set()
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > 0.8:
            colname = correlation_matrix.columns[i]
            unwanted_features.add(colname)

print("\nd) Unwanted features:", unwanted_features)
# Out:
# d) Unwanted features: set()

# %%
# e) Perform data discretization using equi-frequency binning method on the salary attribute
num_bins = 5  # Choose the number of bins as needed
data['Salaries_bins'] = pd.qcut(data['Salaries'], q=num_bins, labels=False)

# %%
# Visualize the equi-frequency bins graphically
plt.figure(figsize=(5, 3))
plt.hist(data['Age'], bins=num_bins, edgecolor='black', alpha=0.7)
plt.title('Equi-Frequency Binning for Age Attribute')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
#Min-Max normalization: This technique scales the values of a feature to a range between 0 and 1. This is done by subtracting the minimum value of the feature from each value, and then dividing by the range of the feature.

#Z-score normalization: This technique scales the values of a feature to have a mean of 0 and a standard deviation of 1. This is done by subtracting the mean of the feature from each value, and then dividing by the standard deviation.

#Decimal Scaling: This technique scales the values of a feature by dividing the values of a feature by a power of 10.

# %%
# f) Normalize RestBP, chol, and MaxHR attributes using different normalization techniques
attributes_to_normalize = ['Salaries','age']

# Min-Max normalization
min_max_scaler = MinMaxScaler()
data_min_max_normalized = data.copy()
data_min_max_normalized[attributes_to_normalize] = min_max_scaler.fit_transform(data[attributes_to_normalize])

# %%
# Z-score normalization
z_score_scaler = StandardScaler()
data_z_score_normalized = data.copy()
data_z_score_normalized[attributes_to_normalize] = z_score_scaler.fit_transform(data[attributes_to_normalize])

# %%
# Decimal scaling normalization
decimal_scaling_factor = 10 ** (len(str(int(data[attributes_to_normalize].abs().max().max()))) - 1)
data_decimal_scaled = data.copy()
data_decimal_scaled[attributes_to_normalize] = data[attributes_to_normalize] / decimal_scaling_factor

# %%
# Display the results
print("\nMin-Max Normalized DataFrame:\n", data_min_max_normalized.head())
print("\nZ-Score Normalized DataFrame:\n", data_z_score_normalized.head())
print("\nDecimal Scaled DataFrame:\n", data_decimal_scaled.head())
# Out:
# Min-Max Normalized DataFrame:
#                     Position State Sex MaritalDesc CitizenDesc  \
# 0              Accountant I   NaN   F     Married  US Citizen
# 1              Accountant I    MA  M     Divorced  US Citizen
# 2              Accountant I    MA  M       Single         NaN
# 3  Administrative Assistant    MA   F         NaN  US Citizen
# 4                       NaN    MA   F      Single  US Citizen
#
#        EmploymentStatus     Department  Salaries       age  \
# 0                Active  Admin Offices  0.005537       NaN
# 1                Active  Admin Offices  0.005537  0.870968
# 2                Active  Admin Offices  0.005537  0.645161
# 3  Terminated for Cause  Admin Offices  0.441166  0.677419
# 4                Active  Admin Offices       NaN  0.322581
#
#                         Race  Salaries_bins
# 0  Black or African American            0.0
# 1  Black or African American            0.0
# 2                      White            0.0
# ...

# %% [markdown]
# #**DMW 3**
#
# #*Dataset Download:https://www.kaggle.com/datasets/arijitdu/supermarket-transactions-data*
#
# #*Dataset: Supermarket Transactions.csv*

# %% [markdown]
# **Construct an FP-tree using suitable programming language for appropriate data set for association rule mining. Explain all the steps of the tree construction and draw the resulting tree.(Minimum support count threshold for association rules [default: 2]) Based on this tree answer the questions:**
#
#  **a) Find maximum frequent itemset.**
#
#  **b) How many transactions does it contain?**
#
#  **c) Simulate frequent pattern enumeration based on the FP-tree constructed**
#
#  **d) Give comparative analysis of this process with Apriori algorithm**.

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import fpgrowth
import graphviz

# %%
import pandas as pd

# Importing dataset with specified encoding
data = pd.read_csv('Supermarket_Transactions.csv')
data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        Transaction Purchase Date  Customer ID Gender Marital Status Homeowner  \
# 0                1    12/18/2011         7223      F              S         Y
# 1                2    12/20/2011         7841      M              M         Y
# 2                3    12/21/2011         8374      F              M         N
# 3                4    12/21/2011         9619      M              M         Y
# 4                5    12/22/2011         1900      F              S         Y
# ...            ...           ...          ...    ...            ...       ...
# ...

# %%
transactions = data['Product Category'].str.split(',')

# Initialize and fit TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

# Create a new DataFrame with the encoded transactions
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Apply the Apriori algorithm
min_support = 0.03  # Set your desired minimum support
frequent_itemsets_apriori = apriori(df_encoded, min_support=min_support, use_colnames=True)

# Display the frequent itemsets
print(frequent_itemsets_apriori)
# Out:
#     support            itemsets
# 0  0.034426      (Baking Goods)
# 1  0.030230             (Bread)
# 2  0.064229             (Dairy)
# 3  0.054414             (Fruit)
# 4  0.041824  (Jams and Jellies)
# 5  0.054129              (Meat)
# 6  0.113806       (Snack Foods)
# 7  0.122911        (Vegetables)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
transactions = data['Product Category'].str.split(',')

# Initialize and fit TransactionEncoder
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)

# Create a new DataFrame with the encoded transactions
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# Apply the FP-growth algorithm
min_support = 0.03  # Set your desired minimum support
frequent_itemsets_fpgrowth = fpgrowth(df_encoded, min_support=min_support, use_colnames=True)

# Display the frequent itemsets
print(frequent_itemsets_fpgrowth)
# Out:
#     support            itemsets
# 0  0.113806       (Snack Foods)
# 1  0.122911        (Vegetables)
# 2  0.034426      (Baking Goods)
# 3  0.054414             (Fruit)
# 4  0.054129              (Meat)
# 5  0.064229             (Dairy)
# 6  0.030230             (Bread)
# 7  0.041824  (Jams and Jellies)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
class Node:
    def __init__(self, name, count, parent):
        self.name = name
        self.count = count
        self.parent = parent
        self.children = {}
        self.node_link = None

def insert_tree(items, node, header_table, count):
    if items[0] in node.children:
        # Increment the count of the existing node
        node.children[items[0]].count += count
    else:
        # Create a new node
        node.children[items[0]] = Node(items[0], count, node)

        # Update the node link in the header table
        if header_table[items[0]][1] is None:
            header_table[items[0]][1] = node.children[items[0]]
        else:
            update_node_link(header_table[items[0]][1], node.children[items[0]])

    # Recursively call the function for the remaining items
    if len(items) > 1:
        insert_tree(items[1:], node.children[items[0]], header_table, count)

def update_node_link(test_node, target_node):
    while test_node.node_link is not None:
        test_node = test_node.node_link
    test_node.node_link = target_node

def build_tree(data, min_support):
    header_table = {}
    for index, row in data.iterrows():
        for item in row:
            header_table[item] = header_table.get(item, 0) + 1

    for k in list(header_table):
        if header_table[k] < min_support:
            del header_table[k]

    frequent_items = list(header_table.keys())
    frequent_items.sort(key=lambda x: header_table[x], reverse=True)

    root = Node("Null", 1, None)

    for index, row in data.iterrows():
        ordered_items = [item for item in frequent_items if item in row]
        if ordered_items:
            insert_tree(ordered_items, root, header_table, 1)

    # Ensure 'Null' is in header_table
    if 'Null' not in header_table:
        header_table['Null'] = (0, None)

    return root, header_table

# Re-run the FP-tree construction
root, header_table = build_tree(df_encoded, min_support=2)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Build the FP-tree
root, header_table = build_tree(df_encoded, min_support=2)

# Visualize the FP-tree
def display_tree(node, depth=0):
    if node is not None:
        print('  ' * depth, node.name, '(', node.count, ')')
        for child_key, child_node in node.children.items():
            display_tree(child_node, depth + 1)

# Display the FP-tree
print("FP-Tree:")
display_tree(root)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# FP-Tree:
#  Null ( 1 )

# %%
# Visualize the FP-tree
def visualize_tree(node, graph, parent_name, graph_name):
    if node is not None:
        graph.node(graph_name, f"{node.name} ({node.count})", shape="box")  # Change node.item to node.name
        if parent_name is not None:
            graph.edge(parent_name, graph_name)
        for child_key, child_node in node.children.items():
            visualize_tree(child_node, graph, graph_name, f"{graph_name}_{child_key}")

# Create a graph using Graphviz
fp_tree_graph = graphviz.Digraph('FP_Tree', node_attr={'shape': 'box'}, graph_attr={'rankdir': 'TB'})
visualize_tree(root, fp_tree_graph, None, 'Root')

# Display the FP-tree visualization
fp_tree_graph.render(filename='fp_tree_visualization', format='png', cleanup=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 'fp_tree_visualization.png'

# %%
#Answer the questions based on the FP-tree:
# a) Find maximum frequent itemset
# Convert support values to numeric in header_table
header_table_numeric = {}

for item, support_node in header_table.items():
    if isinstance(support_node, int):
        support_tuple = (float(support_node), None)
    else:
        support_tuple = (float(support_node[0]), support_node[1])

    header_table_numeric[item] = support_tuple

# Find maximum frequent itemset from FP-tree
max_frequent_item_fp = max(header_table_numeric.items(), key=lambda x: x[1][0])
max_frequent_itemset_fp = pd.DataFrame({'itemsets': [max_frequent_item_fp[0]], 'support': [max_frequent_item_fp[1][0]]})

print("a) Maximum Frequent Itemset (FP-growth):\n", max_frequent_itemset_fp)

# For Apriori, use the same approach as before
max_frequent_itemset_apriori = frequent_itemsets_apriori[frequent_itemsets_apriori['support'] == frequent_itemsets_apriori['support'].max()]
print("a) Maximum Frequent Itemset (Apriori):\n", max_frequent_itemset_apriori)
# Out:
# a) Maximum Frequent Itemset (FP-growth):
#     itemsets   support
# 0     False  618596.0
# a) Maximum Frequent Itemset (Apriori):
#      support      itemsets
# 7  0.122911  (Vegetables)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# b) How many transactions does it contain?
# Filter transactions that contain the maximum frequent itemset
max_frequent_items = set([max_frequent_itemset_fp.iloc[0]['itemsets']])
transactions_containing_max_fp = data[data['Product Category'].apply(
    lambda x: all(item in x.split(',') for item in max_frequent_items))]

# Get the number of transactions containing the maximum frequent itemset
num_transactions_containing_max_fp = len(transactions_containing_max_fp)

print("b) Number of transactions containing the maximum frequent itemset:", num_transactions_containing_max_fp)
# Out:
# b) Number of transactions containing the maximum frequent itemset: 0
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
def build_tree(data, min_support):
    header_table = {}
    for index, row in data.iterrows():
        for item in row:
            header_table[item] = header_table.get(item, 0) + 1

    for k in list(header_table):
        if header_table[k] < min_support:
            del header_table[k]

    # Convert header_table to a dictionary with appropriate format
    header_table = {k: (header_table[k], None) for k in header_table}

    frequent_items = list(header_table.keys())
    frequent_items.sort(key=lambda x: header_table[x][0], reverse=True)

    root = Node("Null", 1, None)

    for index, row in data.iterrows():
        ordered_items = [item for item in frequent_items if item in row]
        if ordered_items:
            insert_tree(ordered_items, root, header_table, 1)

    # Ensure 'Null' is in header_table
    if 'Null' not in header_table:
        header_table['Null'] = (0, None)

    return root, header_table
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# d) Give comparative analysis of this process with Apriori algorithm.
# FP-growth is generally more efficient than Apriori, especially with large datasets, as it avoids the candidate generation step.
# It constructs a compact tree structure, reducing the number of passes over the data compared to Apriori.
# The FP-tree also eliminates the need for candidate itemsets by using a conditional pattern base.

# %% [markdown]
# Comparative Analysis:
# 1. Code Simplicity:
# FP-growth (FP-tree): The FP-growth implementation is generally simpler and involves fewer steps. The key steps are building the FP-tree and mining patterns directly from it.
#
# Apriori Algorithm: The Apriori algorithm involves multiple passes for candidate generation and pruning, making the code more complex.
#
# 2. Time Complexity:
# FP-growth (FP-tree): FP-growth is more time-efficient due to the reduced number of passes over the dataset and the avoidance of explicit candidate generation.
#
# Apriori Algorithm: Apriori involves multiple passes, generating and pruning candidate itemsets at each pass, leading to higher time complexity.
#
# 3. Memory Usage:
# FP-growth (FP-tree): The FP-tree has a more compact representation, requiring less memory.
#
# Apriori Algorithm: Requires additional memory to store candidate itemsets, potentially becoming memory-intensive for large datasets.
#
# 4. Candidate Generation:
# FP-growth (FP-tree): No explicit candidate generation step is needed, reducing computational overhead.
#
# Apriori Algorithm: Requires multiple passes for candidate generation, making it computationally expensive.
#
# 5. Scalability:
# FP-growth (FP-tree): Scales well with larger datasets due to fewer passes and memory requirements.
#
# Apriori Algorithm: May face scalability challenges, especially with a large number of transactions and items.
#
# Conclusion:
# FP-growth (FP-tree) is generally preferred for its simplicity, time efficiency, and scalability, particularly with larger datasets.
#
# The Apriori algorithm is still valuable, especially for educational purposes or when the dataset is not particularly large.
#
# The choice between the two algorithms depends on factors such as dataset characteristics, implementation requirements, and available computational resources.
